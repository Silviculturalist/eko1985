# %%
# Out:
# age_brh age_tot  hdom  DG_bef  N_bef   G_bef    V_bef  DG_aft  N_aft   G_aft    V_aft  DG_thin  N_thin  G_thin   V_thin  pctN  pctV
# -----------------------------------------------------------------------------------------------------------------------------------
#   21.00   28.00  12.48  11.66   1151  12.300     69.1  11.66   1151  12.300     69.1    0.00    0.0   0.000      0.0   0.0   0.0
#   27.00   34.00  15.36  15.06   1151  20.509    141.5  15.98    737  14.767    102.6   13.28  414.4   5.743     39.0  36.0  27.6
#   30.00   37.00  16.69  17.74    734  18.144    137.0  17.74    734  18.144    137.0    8.37    2.4   0.013      0.1   0.3   0.1
#   34.00   41.00  18.35  19.74    731  22.374    185.3  20.11    585  18.570    154.2   18.06  149.4   3.827     31.4  20.4  16.9
#   42.00   49.00  21.32  23.91    582  26.130    251.3  24.38    436  20.381    196.5   22.27  148.4   5.779     55.1  25.5  21.9
# ...

# %%
from pyforestry.sweden.siteindex.hagglund_1970 import (
    HagglundSpruceModel,
)
from pyforestry.base.helpers import Age

# %%
age1 = Age.TOTAL(34)
age2 = Age.TOTAL(44)
print(HagglundSpruceModel.southern_sweden(4.5, age=age1, age2=age2))
# Out:
# (SiteIndexValue(6.575490035852826, reference_age=AgeMeasurement(44.0, code=1 [TOTAL]), species={TreeName(genus=TreeGenus(name='Picea', code='PICEA'), species_name='abies', code='PAB')}, fn=wrapper), np.float64(13.880678243754218))
# C:\Users\csvi0001\AppData\Local\Temp\ipykernel_59204\2708484205.py:3: UserWarning: Too low productivity, outside of the material.
#   print(HagglundSpruceModel.southern_sweden(4.5,age=age1,age2=age2))
